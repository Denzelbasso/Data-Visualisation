# %%
path = 'https://raw.githubusercontent.com/Denzelbasso/Data-Visualisation/dataset/master/'
#'/andremforte/FinalProjectDV/master/'
#Dataframes of specific quantities imported by nation
pt_qimp = pd.read_excel(path + ('ITC - Lista da quantidade importada do produto 2204 por Portugal, entre 2003-2022.xlsx').replace(" ", "%20"))
pt_qimp
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 4>()
#       1 path = 'https://raw.githubusercontent.com/Denzelbasso/Data-Visualisation/dataset/master/'
#       2 #'/andremforte/FinalProjectDV/master/'
#       3 #Dataframes of specific quantities imported by nation
# ----> 4 pt_qimp = pd.read_excel(path + ('ITC - Lista da quantidade importada do produto 2204 por Portugal, entre 2003-2022.xlsx').replace(" ", "%20"))
#       5 pt_qimp
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
##### LOADING THE DATA #######################################################################################
path = 'https://raw.githubusercontent.com/Denzelbasso/Data-Visualisation/main/dataset/'
#Dataframes of specific quantities imported by nation
pt_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 por Portugal, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
es_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 por Espanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
fr_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 pela França, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
de_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 pela Alemanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
it_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 pela Itália, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#Dataframes of overall quantities imported by nation
w_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 por Países, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")

#Dataframes of specific value imported by nation
pt_vimp = pd.read_excel((path + 'ITC - Lista do valor importado do produto 2204 por Portugal, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
es_vimp = pd.read_excel((path + 'ITC - Lista do valor importado do produto 2204 por Espanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
fr_vimp = pd.read_excel((path + 'ITC - Lista do valor importado do produto 2204 pela França, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
de_vimp = pd.read_excel((path + 'ITC - Lista do valor importado do produto 2204 pela Alemanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
it_vimp = pd.read_excel((path + 'ITC - Lista do valor importado do produto 2204 pela Itália, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#Dataframes of overall value imported by nation
w_vimp = pd.read_excel((path + 'ITC - Lista do valor importado do produto 2204 por Países, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#Dataframes of specific quantities exported by nation
pt_qexp = pd.read_excel((path + 'ITC - Lista da quantidade exportada do produto 2204 por Portugal, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
es_qexp = pd.read_excel((path + 'ITC - Lista da quantidade exportada do produto 2204 por Espanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
fr_qexp = pd.read_excel((path + 'ITC - Lista da quantidade exportada do produto 2204 pela França, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
de_qexp = pd.read_excel((path + 'ITC - Lista da quantidade exportada do produto 2204 pela Alemanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
it_qexp = pd.read_excel((path + 'ITC - Lista da quantidade exportada do produto 2204 pela Itália, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#Dataframes of overall quantities exported by nation
w_qexp = pd.read_excel((path + 'ITC - Lista da quantidade exportada do produto 2204 por Países, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#Dataframes of specific value exported by nation
pt_vexp = pd.read_excel((path + 'ITC - Lista do valor exportado do produto 2204 por Portugal, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
es_vexp = pd.read_excel((path + 'ITC - Lista do valor exportado do produto 2204 por Espanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
fr_vexp = pd.read_excel((path + 'ITC - Lista do valor exportado do produto 2204 pela França, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
de_vexp = pd.read_excel((path + 'ITC - Lista do valor exportado do produto 2204 pela Alemanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
it_vexp = pd.read_excel((path + 'ITC - Lista do valor exportado do produto 2204 pela Itália, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#Dataframes of overall quantities exported by nation
w_vexp = pd.read_excel((path + 'ITC - Lista do valor exportado do produto 2204 por Países, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#Function to remove empty lines
def df_fixer_qimp(df, n, exi):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df = df.rename(columns=df.iloc[0])
    df = df.replace("No Quantity", np.nan)
    df = df.replace(0, np.nan)
    df = df.astype(str)
    df = df.set_index(exi)
    df = df.drop(exi)
    df = df.iloc[1:]
    df = df.astype(float)
    return df

def df_fixer_wqimp(df, n, exi):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df = df.rename(columns=df.iloc[0])
    df = df.replace("No Quantity", np.nan)
    df = df.replace(0, np.nan)
    df = df.astype(str)
    df = df.set_index(exi)
    df = df.drop(exi)
    df = df.iloc[1:]
    df = df.iloc[:, np.arange(len(df.columns)) % 2 == 0]
    df = df.astype(float)
    return df

def df_fixer_wqimp2(df, n, exi):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df = df.rename(columns=df.iloc[0])
    df = df.replace("No Quantity", np.nan)
    df = df.replace(0, np.nan)
    df = df.astype(str)
    df = df.set_index(exi)
    df = df.drop(exi)
    df = df.iloc[1:]
    df = df.astype(float)
    return df

def df_fixer_vimp(df, n, exi, column_retriever):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df.columns=df.iloc[0]
    df.columns = df.columns.str.replace(column_retriever, '')
    df = df.set_index(exi)
    df = df.iloc[1:]
    df = df.astype(float)
    return df
##### NEW DFS ################################################################################################
#######Value imported
#By country
pt_vimp = df_fixer_vimp(pt_vimp ,14, "Exporters", 'Imported value in ')
fr_vimp = df_fixer_vimp(fr_vimp ,13, "Exporters", 'Imported value in ')
es_vimp = df_fixer_vimp(es_vimp ,14, "Exporters", 'Imported value in ')
de_vimp = df_fixer_vimp(de_vimp ,13, "Exporters", 'Imported value in ')
it_vimp = df_fixer_vimp(it_vimp ,13, "Exporters", 'Imported value in ')
#World
w_vimp = df_fixer_wqimp2(w_vimp ,12, "Importers")
w_vimp.columns = w_vimp.columns.str.replace('Imported value in ', '')
#######Value exported
#By country
pt_vexp = df_fixer_vimp(pt_vexp ,14, "Importers", 'Exported value in ')
fr_vexp = df_fixer_vimp(fr_vexp ,13, "Importers", 'Exported value in ')
es_vexp = df_fixer_vimp(es_vexp ,14, "Importers", 'Exported value in ')
de_vexp = df_fixer_vimp(de_vexp ,13, "Importers", 'Exported value in ')
it_vexp = df_fixer_vimp(it_vexp ,13, "Importers", 'Exported value in ')
#World
w_vexp = df_fixer_wqimp2(w_vexp ,12, "Exporters")
w_vexp.columns = w_vexp.columns.str.replace('Exported value in ', '')
#########Quantity imported
#By country
pt_qimp = df_fixer_qimp(pt_qimp, 13, "Exporters")
es_qimp = df_fixer_qimp(es_qimp, 13, "Exporters")
fr_qimp = df_fixer_qimp(fr_qimp, 12, "Exporters")
de_qimp = df_fixer_qimp(de_qimp, 12, "Exporters")
it_qimp = df_fixer_qimp(it_qimp, 12, "Exporters")
#World
w_qimp = df_fixer_wqimp(w_qimp, 12, "Importers")
w_qimp = w_qimp.iloc[1:]
##########Quantity exported
#By country
pt_qexp = df_fixer_qimp(pt_qexp, 14, "Importers")
es_qexp = df_fixer_qimp(es_qexp, 14, "Importers")
fr_qexp = df_fixer_qimp(fr_qexp, 13, "Importers")
de_qexp = df_fixer_qimp(de_qexp, 13, "Importers")
it_qexp = df_fixer_qimp(it_qexp, 13, "Importers")
#World
w_qexp = df_fixer_wqimp(w_qexp, 12, "Exporters")
w_qexp = w_qexp.iloc[1:]
#......................................................... need to be modify after this


##### OPTIONS #################################################################################################
years = list(set(np.array(races['year'])))
circuits = list(set(np.array(df['circuit'])))

years_circuits = list(set(np.array(lap_times_2['year'])))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Input In [13], in <cell line: 6>()
#       4 pt_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 por Portugal, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#       5 es_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 por Espanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
# ----> 6 fr_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 pela França, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#       7 de_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 pela Alemanha, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
# ...

# %%
path = 'https://raw.githubusercontent.com/Denzelbasso/Data-Visualisation/main/dataset/'
#Dataframes of specific quantities imported by nation
pt_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 pela França, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
pt_qimp
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 path = 'https://raw.githubusercontent.com/Denzelbasso/Data-Visualisation/main/dataset/'
#       2 #Dataframes of specific quantities imported by nation
# ----> 3 pt_qimp = pd.read_excel((path + 'ITC - Lista da quantidade importada do produto 2204 pela França, entre 2003-2022.xlsx').replace(" ", "%20"), sheet_name = "Folha1")
#       4 pt_qimp
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
path = 'https://raw.githubusercontent.com/andremforte/FinalProjectDV/master/'
pt_qimp = pd.read_excel(path + 'quality_life_index.xlsx')
pt_qimp

# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
import xlrd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import requests

# %%
#Dataframes of specific quantities imported by nation
pt_qimp = pd.read_excel('ITC - Lista da quantidade importada do produto 2204 por Portugal, entre 2003-2022.xlsx', sheet_name = "Folha1")  
es_qimp = pd.read_excel('ITC - Lista da quantidade importada do produto 2204 por Espanha, entre 2003-2022.xlsx', sheet_name = "Folha1") 
fr_qimp = pd.read_excel('ITC - Lista da quantidade importada do produto 2204 pela França, entre 2003-2022.xlsx', sheet_name = "Folha1")  
de_qimp = pd.read_excel('ITC - Lista da quantidade importada do produto 2204 pela Alemanha, entre 2003-2022.xlsx', sheet_name = "Folha1")  
it_qimp = pd.read_excel('ITC - Lista da quantidade importada do produto 2204 pela Itália, entre 2003-2022.xlsx', sheet_name = "Folha1")  
#Dataframes of overall quantities imported by nation
w_qimp = pd.read_excel('ITC - Lista da quantidade importada do produto 2204 por Países, entre 2003-2022.xlsx', sheet_name = "Folha1")

#Dataframes of specific value imported by nation
pt_vimp = pd.read_excel('ITC - Lista do valor importado do produto 2204 por Portugal, entre 2003-2022.xlsx', sheet_name = "Folha1")  
es_vimp = pd.read_excel('ITC - Lista do valor importado do produto 2204 por Espanha, entre 2003-2022.xlsx', sheet_name = "Folha1") 
fr_vimp = pd.read_excel('ITC - Lista do valor importado do produto 2204 pela França, entre 2003-2022.xlsx', sheet_name = "Folha1")  
de_vimp = pd.read_excel('ITC - Lista do valor importado do produto 2204 pela Alemanha, entre 2003-2022.xlsx', sheet_name = "Folha1")  
it_vimp = pd.read_excel('ITC - Lista do valor importado do produto 2204 pela Itália, entre 2003-2022.xlsx', sheet_name = "Folha1")  
#Dataframes of overall value imported by nation
w_vimp = pd.read_excel('ITC - Lista do valor importado do produto 2204 por Países, entre 2003-2022.xlsx', sheet_name = "Folha1")

# %%
#Dataframes of specific quantities exported by nation
pt_qexp = pd.read_excel('ITC - Lista da quantidade exportada do produto 2204 por Portugal, entre 2003-2022.xlsx', sheet_name = "Folha1")  
es_qexp = pd.read_excel('ITC - Lista da quantidade exportada do produto 2204 por Espanha, entre 2003-2022.xlsx', sheet_name = "Folha1") 
fr_qexp = pd.read_excel('ITC - Lista da quantidade exportada do produto 2204 pela França, entre 2003-2022.xlsx', sheet_name = "Folha1")  
de_qexp = pd.read_excel('ITC - Lista da quantidade exportada do produto 2204 pela Alemanha, entre 2003-2022.xlsx', sheet_name = "Folha1")  
it_qexp = pd.read_excel('ITC - Lista da quantidade exportada do produto 2204 pela Itália, entre 2003-2022.xlsx', sheet_name = "Folha1")  
#Dataframes of overall quantities exported by nation
w_qexp = pd.read_excel('ITC - Lista da quantidade exportada do produto 2204 por Países, entre 2003-2022.xlsx', sheet_name = "Folha1")

# %%
#Dataframes of specific value exported by nation
pt_vexp = pd.read_excel('ITC - Lista do valor exportado do produto 2204 por Portugal, entre 2003-2022.xlsx', sheet_name = "Folha1")  
es_vexp = pd.read_excel('ITC - Lista do valor exportado do produto 2204 por Espanha, entre 2003-2022.xlsx', sheet_name = "Folha1") 
fr_vexp = pd.read_excel('ITC - Lista do valor exportado do produto 2204 pela França, entre 2003-2022.xlsx', sheet_name = "Folha1")  
de_vexp = pd.read_excel('ITC - Lista do valor exportado do produto 2204 pela Alemanha, entre 2003-2022.xlsx', sheet_name = "Folha1")  
it_vexp = pd.read_excel('ITC - Lista do valor exportado do produto 2204 pela Itália, entre 2003-2022.xlsx', sheet_name = "Folha1")
#Dataframes of overall quantities exported by nation
w_vexp = pd.read_excel('ITC - Lista do valor exportado do produto 2204 por Países, entre 2003-2022.xlsx', sheet_name = "Folha1")

# %%
#Função para remover as linhas em vazio
def df_fixer_qimp(df, n, exi):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df = df.rename(columns=df.iloc[0])
    df = df.replace("No Quantity", np.nan)
    df = df.replace(0, np.nan)
    df = df.astype(str)
    df = df.set_index(exi)
    df = df.drop(exi)
    df = df.iloc[1:]
    df = df.astype(float)
    return df

def df_fixer_wqimp(df, n, exi):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df = df.rename(columns=df.iloc[0])
    df = df.replace("No Quantity", np.nan)
    df = df.replace(0, np.nan)
    df = df.astype(str)
    df = df.set_index(exi)
    df = df.drop(exi)
    df = df.iloc[1:]
    df = df.iloc[:, np.arange(len(df.columns)) % 2 == 0]
    df = df.astype(float)
    return df

def df_fixer_wqimp2(df, n, exi):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df = df.rename(columns=df.iloc[0])
    df = df.replace("No Quantity", np.nan)
    df = df.replace(0, np.nan)
    df = df.astype(str)
    df = df.set_index(exi)
    df = df.drop(exi)
    df = df.iloc[1:]
    df = df.astype(float)
    return df

def df_fixer_vimp(df, n, exi, column_retriever):
    index_list = range(n)
    df.drop(df.index[index_list], inplace=True)
    df.columns=df.iloc[0] 
    df.columns = df.columns.str.replace(column_retriever, '')
    df = df.set_index(exi)
    df = df.iloc[1:]
    df = df.astype(float)
    return df

# %%
#Value imported

#By country
pt_vimp = df_fixer_vimp(pt_vimp ,14, "Exporters", 'Imported value in ')
fr_vimp = df_fixer_vimp(fr_vimp ,13, "Exporters", 'Imported value in ')
es_vimp = df_fixer_vimp(es_vimp ,14, "Exporters", 'Imported value in ')
de_vimp = df_fixer_vimp(de_vimp ,13, "Exporters", 'Imported value in ')
it_vimp = df_fixer_vimp(it_vimp ,13, "Exporters", 'Imported value in ')
#World
w_vimp = df_fixer_wqimp2(w_vimp ,12, "Importers")
w_vimp.columns = w_vimp.columns.str.replace('Imported value in ', '')

# %%
#Value exported

#By country
pt_vexp = df_fixer_vimp(pt_vexp ,14, "Importers", 'Exported value in ')
fr_vexp = df_fixer_vimp(fr_vexp ,13, "Importers", 'Exported value in ')
es_vexp = df_fixer_vimp(es_vexp ,14, "Importers", 'Exported value in ')
de_vexp = df_fixer_vimp(de_vexp ,13, "Importers", 'Exported value in ')
it_vexp = df_fixer_vimp(it_vexp ,13, "Importers", 'Exported value in ')
#World
w_vexp = df_fixer_wqimp2(w_vexp ,12, "Exporters")
w_vexp.columns = w_vexp.columns.str.replace('Exported value in ', '')

# %%
#Quantity imported

#By country
pt_qimp = df_fixer_qimp(pt_qimp, 13, "Exporters")
es_qimp = df_fixer_qimp(es_qimp, 13, "Exporters")
fr_qimp = df_fixer_qimp(fr_qimp, 12, "Exporters")
de_qimp = df_fixer_qimp(de_qimp, 12, "Exporters")
it_qimp = df_fixer_qimp(it_qimp, 12, "Exporters")
#World
w_qimp = df_fixer_wqimp(w_qimp, 12, "Importers")
w_qimp = w_qimp.iloc[1:]

# %%
#Quantity exported

#By country
pt_qexp = df_fixer_qimp(pt_qexp, 14, "Importers")
es_qexp = df_fixer_qimp(es_qexp, 14, "Importers")
fr_qexp = df_fixer_qimp(fr_qexp, 13, "Importers")
de_qexp = df_fixer_qimp(de_qexp, 13, "Importers")
it_qexp = df_fixer_qimp(it_qexp, 13, "Importers")
#World
w_qexp = df_fixer_wqimp(w_qexp, 12, "Exporters")
w_qexp = w_qexp.iloc[1:]

# %%
w_qimp

# %%
w_vimp

# %%
w_vimp.loc[["Ghana"]]

# %%
w_vexp.loc["Portugal"].index

# %%
w_vexp.columns

# %%
colors = ['red']

TOPcountries = ['Portugal', 'Spain', 'Italy', 'Germany', 'France']

data_scatter = []

for i in TOPcountries:
    data_scatter.append(dict(type='scatter',
                     x=w_vexp.columns,
                     y=w_vexp.loc[i],
                     name= i,
                     showlegend=True
                    )
               )

layout_scatter = dict(title=dict(
                        text='Portugal value exportation of wine from 1990 until 2015'
                        ),
                  xaxis=dict(title='Years'),
                  yaxis=dict(title='Wine value export'),
                     )

fig_scatter = go.Figure(data=data_scatter, layout=layout_scatter)

fig_scatter.show(renderer='iframe')

# %%
#Top 5 countries in wine exportation from 2003 until 2022

TOPcountries = ['Portugal', 'Spain', 'Italy', 'Germany', 'France']

data_scatter = []

for i in TOPcountries:
    data_scatter.append(dict(type='scatter',
                     x=w_vexp.columns,
                     y=w_vexp.loc[i],
                     name= i,
                     showlegend=True
                    )
               )

layout_scatter = dict(title=dict(
                        text='Portugal value exportation of wine from 2003 until 2022'
                        ),
                  xaxis=dict(title='Years'),
                  yaxis=dict(title='Wine value export'),
                     paper_bgcolor='azure',
                    plot_bgcolor= 'purple'
                     )

fig_scatter = go.Figure(data=data_scatter, layout=layout_scatter)
fig_scatter.show(renderer='iframe')

# %%
data_scatter1 = [dict(type='scatter',
                    x=w_vexp.columns,
                    y=w_vexp.loc["Portugal"],
                    name='Portugal',
                    showlegend=True
                    )]

# %%
data_choropleth = dict(type='choropleth',
                       locations=w_vexp.index,
                       locationmode='country names',
                       z=np.log(w_vexp.iloc[:, -2]),  # Use iloc to select the last column as an array
                       text=w_vexp.index,
                       colorscale='PuRd'
                      )

layout_choropleth = dict(
    geo=dict(
        scope='world',
        showland=True,
        landcolor='grey',
        lakecolor='white',
        showocean=True,
        oceancolor='azure'
    ),
    title=dict(text='World map of exported wine by country, thousands of euros, 2021',
               font=dict(size=25,family='Times New Roman', color='darkred'),
               x=0.5, y=0.9
              ),
    annotations=[
        dict(
            x=0.08,
            y=-0.1,
            xref='paper',
            yref='paper',
            text='Source: International Trace Cente 2023',
            showarrow=False,
            font=dict(size=14, family='Times New Roman', color='darkred')
        )
    ]
)
fig_choropleth = go.Figure(data=data_choropleth, layout=layout_choropleth)
fig_choropleth.show()

# %%
# An empty graph object
fig_bar = go.Figure()

# Each year defines a new hidden (implies visible=False) trace in our visualization
for year in w_vexp.columns:
    fig_bar.add_trace(dict(type='bar',
                     x=w_vexp.index,
                     y=w_vexp[year],
                     name=year,
                     showlegend=False,
                     visible=False
                    )
               )

# First seen trace
fig_bar.data[0].visible = True


# Lets create our slider, one option for each trace
steps = []
for i in range(len(fig_bar.data)):
    step = dict(
        label='Year ' + str(2002 + i),
        method="restyle", #there are four methods restyle changes the type of an argument (in this case if visible or not)
        args=["visible", [False] * len(fig_bar.data)], # Changes all to Not visible
    )
    step["args"][1][i] = True  # Toggle i'th trace to "visible"
    steps.append(step)

    
sliders = [dict(
    active=1990,
    pad={"t": 100},
    steps=steps
)]


fig_bar.update_layout(dict(title=dict(text='Emissions by region comparison in 1990 and 2014'),
                  yaxis=dict(title='Emissions',
                             range=[0,2*(10**4)]
                            ),
                  sliders=sliders))

fig_bar.show(renderer='iframe')

# %%
# bachart to indicate the specific countries that the country selected importes/exports the mos

# %%
dataFrame = pt_vexp.copy()
dataFrame = dataFrame.drop('World')

# %%
dataFrame_fr = fr_vexp.copy()
dataFrame_fr = dataFrame_fr.drop('World')

dataFrame_es = es_vexp.copy()
dataFrame_es = dataFrame_es.drop('World')

dataFrame_de = de_vexp.copy()
dataFrame_de = dataFrame_de.drop('World')

dataFrame_it = it_vexp.copy()
dataFrame_it = dataFrame_it.drop('World')

# %%
#create dataframe with both max value and respective country for each of the 5 countries
print(dataFrame['2022'].max())
print(dataFrame['2022'].idxmax())

# %%
# Here we use a column with categorical data
#fig = px.histogram(f, x="Month", category_orders=dict(Month=["January", "February", "March", "April",
             #                                                "May", "June", "July", "August", "September",
    # #                                                       "October", "November", "December"]))
#fig.show()

# %%
import pandas as pd

# select the '2022' column from each table
dataFrame_fr = dataFrame_fr[['2022']]
dataFrame_es = dataFrame_es[['2022']]
dataFrame_de = dataFrame_de[['2022']]
dataFrame_it = dataFrame_it[['2022']]
dataFrame = dataFrame[['2022']]

# merge the 5 columns into a single table
merged_table = pd.concat([dataFrame_fr, dataFrame_es, dataFrame_de, dataFrame_it, dataFrame], axis=1)

# %%
# rename the columns
merged_table.columns = ['fr', 'es', 'de', 'it', 'pt']

merged_table

# %%
exports_2022 = merged_table.T

# %%
max_values = exports_2022.max(axis=1)
max_columns = exports_2022.idxmax(axis=1)

# merge maximum values and column names into single dataframe
max_exports_destination = pd.concat([max_values, max_columns], axis=1)
max_exports_destination.columns = ['export_value', 'country']

max_exports_destination.head()

# %%
# create histogram with facet_col
fig = px.histogram(max_exports_destination, x='export_value', 
                   category_orders={'table': ['fr', 'es', 'de', 'it', 'pt']})

fig.update_layout(
    xaxis_title='Exportations',
    yaxis_title='Count'
)

fig.show()

# %%
# create histogram
fig = px.histogram(max_exports_destination, x='export_value')
fig.update_xaxes(title='Max Value')
fig.update_yaxes(title='Count')


fig.update_layout(xaxis_ticktext=['France to the US', 'Spain to Germany', 'De to the Netherlands', 
                    'Italy to US', 'Portugal to France'])

fig.show()
